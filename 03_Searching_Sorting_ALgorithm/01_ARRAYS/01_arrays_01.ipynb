# %% [markdown]
# ### ARRAYS. ###
# - An array is a collection of elements stored in contigous memory location. all elements of array of same data type(int,float,etc). Array allow for eficient access and manipulation of data.
# - fixed size , arr[5]
# - homogeneous in nature.
#
# - In python we use "list" instead of "arrays" as they provide more flexibility. However , python provide ability to use array via liabraries such as numpy and array.
#
# # diffrence between list and arrays
# - arrays :- (1)data types:- homogeneous{same type} (2)flexibility:- fixed size
# (3)performance:- more memoryeficient for large data. (4)usage in python:- use array or numpy.
#
# - list:- (1)data types:-heterogeneous(diffrent type). (2)flexibility:-dynamic(can grow amd shrink) (3)performance:-slower for longer dataset.(4)usage in python:- Built in

# %%
# introduction to array
import array
arr = array.array('i',[1,2,3,4,5])
arr[0]=25
print(arr)
# Out:
# array('i', [25, 2, 3, 4, 5])
