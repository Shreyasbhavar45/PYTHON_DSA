# %% [markdown]
# ## Objects - Mutable and Immutable in Python.

# %%
'''## Mutable :- Thing is Changeable..'''
'''### Immutable :- Thing are not changeable'''

### identify is use check the mutable and immutable.
## value is not use to check the mutable and immutable..

#1
sugar_count = 2
print(f'For the first sugar Count:-{sugar_count}')

#2..
spice_mix =set()
print(f'Initial Space Mix Id: {id(spice_mix)}')
print(f'Initial Space Mix Id: {spice_mix}')
spice_mix.add('Ginger')
spice_mix.add('cardamon')
spice_mix.add('lemon')
spice_mix.add('orange')
print(f'Initial Space Mix id: {spice_mix}')
print(f'Initial Space Mix id: {id(spice_mix)}')
# Out:
# For the first sugar Count:-2
# Initial Space Mix Id: 4426651616
# Initial Space Mix Id: set()
# Initial Space Mix id: {'cardamon', 'Ginger', 'orange', 'lemon'}
# Initial Space Mix id: 4426651616

# %% [markdown]
# ## Number Booleans And operator...

# %%
'''boolean = True Or False
            True=(1) and False=(0)'''
## logical operator
'''
and = chai and biscuit
or = chai or coffee
not
'''
# Out:
# 7

# %% [markdown]
# ### String and Indexing or slicing and Encoding...

# %%
## indexing
###[start:end:step]
name ="Shreyas Rajaram Bhavar"
print(f'indexing from last:-{name[::-1]}')

###[start:end:step(jumping)]
name ="Shreyas Rajaram Bhavar"
print(f'{name[0:23:3]}')
# Out:
# indexing from last:-ravahB marajaR sayerhS
# Sesar ar
