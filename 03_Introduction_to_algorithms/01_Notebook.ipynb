# %% [markdown]
# ## Introduction to Algorithms And Apriori Analysis .

# %% [markdown]
# # #What is algorithm?
# - sequence of finite steps to perform same specific task.[**finite steps = it must end**]
#
# # properties..
# - 1) It should terminate after finite amount of time.
# - 2) Produce atleast one output. - eg:-(1)Multiplication (2)Division.
# - 3) Independent of any programming language.
# - 4) Unambigious -> Deterministic:- Whenever you run the code it give answer.
#
# # Example :-
# - {while (True):
# -   print("Rohit Sharma")}_ Its Not Valid Algorithm.because its not finite..

# %%
# Steps to constuct an algorithm
'''  
(1) Problem Definition.
(2) Design The Algo.
##- [approaches]-->##
(1) Divide and Conquer.
(2) Greedy Algorithm
(3) Dynamic Programming
(4) Many More
....
(3)Draw and Flowchart:-(1)Test Cases -->input and Output
(4)Testing
(5)Implementation:-
(6)Analysis:- When We want to Compare Multiple Soln For given Problem(for Optimising..)
------(1)---->Time Complexity...(lesser Time Need.)(Time Required.)
------(2)---->Space Complexity...(extra Space In system.(<->lesser))*

'''
# Out:
# '  \n(1) Problem Definition.\n(2) Design The Algo.\n##- [approaches]-->##\n(1) Divide and Conquer.\n(2) Greedy Algorithm\n(3) Dynamic Programming\n(4) Many More\n....\n(3)Draw and Flowchart:-(1)Test Cases -->input and Output\n(4)Testing\n(5)Implementation:-\n(6)Analysis:- When We want to Compare Multiple Soln For given Problem(for Optimising..)\n------(1)---->Time Complexity...(lesser Time Need.)(Time Required.)\n------(2)---->Space Complexity...(extra Space In system.(<->lesser))*\n\n\n\n'

# %%
n = 29
while i<n:
    i=i*(23)
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 n = 29
# ----> 2 while i<n:
#       3     i=i*(23)
#       4     print(i)
#
# NameError: name 'i' is not defined

# %%
i = 1
while i<40:
    i=2*i
    i=3*i
    print(i)
# Out:
# 6
# 36
# 216
