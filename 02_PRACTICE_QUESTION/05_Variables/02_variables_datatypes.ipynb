# %% [markdown]
# ### Questions

# %%
#1. Identify data type
a = input("enter the name:")#gives the answer in string.
b = int(input("Enter the number:-"))## give the answer in integer.
c = float(input("Enter the number:-"))## give the answer in float.
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
##2 convert int to float.
num = 5
num_float = float(num)
print(num_float)
print(type(num_float))
# Out:
# 5.0
# <class 'float'>

# %%
##3. Convert float to int
num = 5.0
num_int =int(num)
print(num_int)
print(type(num_int))
# Out:
# 5
# <class 'int'>

# %%
##4. Convert string to int
name = "8"## we can only give the input of numbers to convert the string into integer
name_int =int(name)
print(name_int)
print(type(name_int))
# Out:
# 8
# <class 'int'>

# %%
# 5. Boolean variable
is_python_easy = True
is_java_easy = False

print(is_python_easy)
print(is_java_easy)
print(type(is_python_easy))
# Out:
# True
# False
# <class 'bool'>

# %%
##6. Multiple assignment
name, age, city = "shreyas",18,"Nashik"
print(f"name: {name} age: {age} city: {city}")
# Out:
# name: shreyas age: 18 city: Nashik

# %%
## 7. Assign same value to many variables
age=name=country=number="shreyas"
print(age,name,country,number)
# Out:
# shreyas shreyas shreyas shreyas

# %%
##8. Take two inputs in one line.
a = input("Enter the first numbe:-")

print(a.split())
# Out:
# ['9,8']

# %%
##9. Calculate average
a = int(input("Enter the first number:-"))
b = int(input("Enter the second number:-"))
c = int(input("Enter the third Number:-"))
avg = (a+b+c)/3
print("Average",avg)
# Out:
# Average 5.333333333333333

# %%
#10. Calculate percentage
obtained_marks = float(input("Enter obtained marks: "))#459
total_marks = float(input("Enter total marks: "))#600

percentage = (obtained_marks/total_marks)*100
print("percentage:-",percentage)
# Out:
# percentage:- 76.5

# %%
#11. Area of square
side = int(input("enter the number"))
area = side **2
print("area of square:-",area)
# Out:
# area of square:- 64

# %%
## 12. Area of rectangle
length = int(input("enter the Length:-"))
breadth = int(input("enter the breadth:-"))
area = length*breadth
print('area of rectangle:-',area)
# Out:
# area of rectangle:- 63

# %%
##13. Area of circle
r = float(input("enter the radius:-"))
area = 3.14*r*r
print("Area of Circle:-",area)
# Out:
# Area of Circle:- 200.96

# %%
#14. Simple interest
Principal =float(input("Enter the Principal:-"))
Rate =float(input("Enter the Rate:-"))
Time =float(input("Enter the Time:-"))
SI = (Principal*Rate*Time) / 100
print("simple interest",SI)
# Out:
# simple interest 20.3

# %%
#15. Compound interest
principal = float(input("Enter the principal amount: "))
rate = float(input("Enter the rate of interest: "))
time = float(input("Enter the time (in years): "))

amount = principal * (1 + rate/100) ** time
print("Final Amount:", amount)
# Out:
# Final Amount: 2.533695802185596e+20

# %%
## 16. Speed calculation
'''calculate distance'''
distance = int(input("Enter The distance:-"))
time = int(input("Enter the Time:-"))
speed =distance/time #formula...
print("speed calculation is:-",speed)
# Out:
# speed calculation is:- 0.7738095238095238
