# %% [markdown]
# ## Questions.

# %%
i = 1
total=0
while i<10:
    total=total+i
    print(total)
    i=i+1
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45

# %%
## Q1: print("Hello world")

print("Hello World")
# Out:
# Hello World

# %%
## Q2: Print Your name.
print("shreyas")
# Out:
# shreyas

# %%
## Q3: Take input and print it.
'''a = input("Enter The Name:-")
print(a)'''

## corect way
'''we can declare variable as an name as user_variable(so we can know properly that this is the user name.)'''
user_name = input("Enter The Name:-")
print(user_name)

# %%
# Q4: Take two numbers from user and print their sum.
user_num1 = int(input("Enter The first Number:-"))#8
user_num2 = int(input("Enter The second Number:-"))#6
#sum = (user_num1+user_num2)## not a mistake. ''' but we can use {total} it looks good to read.
total = user_num1+user_num2  # 8+6=14
print("sum of Two number is:-",total)#sum of two numbers is :-14
# Out:
# sum of Two number is:- 14

# %%
## Q5:Subtract two numbers.
num1 = int(input("Enter the First Number:-"))#8
num2 = int(input("Enter the Second Number:-"))#6
# total = num1-num2. # not a miastake . '''but instead of that we can use difference'''
diffrence = num1-num2 ##diff = 8-6=2
print("subtraction of Two numbers:-",diffrence)#2
# Out:
# subtraction of Two numbers:- 2

# %%
#6. Multiply two numbers
num1 = int(input("Enter the First Number:-"))#8
num2 = int(input("Enter the Second Number:-"))#6
num3 = 8
#multiplication = num1*num2 # 8*6=48 '''{instead of multiplication variable use (product)variable}
product = num1*num2*num3 #8*6=48
print("Multiplication of two Numbers:-",product)#48
# Out:
# Multiplication of two Numbers:- 128

# %%
#7. Divide two numbers
num1 = int(input("Enter the First Number:-"))#50
num2 = int(input("Enter the Second Number:-"))#2
separation =(num1/num2)#50/2=25
print("division of Two number:-",separation)#ans=25
# Out:
# division of Two number:- 25.0

# %%
#8. Find remainder
a = 8
b =4
remainder =a%b
print("The reaminder of two number is:-",remainder)
# Out:
# The reaminder of two number is:- 0

# %%
###9: Square of a numberggg
num = int(input("Enter the First Number:-"))
square = (num*num)
print("Square of the Number:-",square)
# Out:
# Square of the Number:- 49

# %%
#👉 10 cube 0f number
num = int(input("enter the number:-"))
cube= (num**3)
print("Cube of the number:-",cube)
# Out:
# Cube of the number:- 27

# %%
#11 swap two numbers
num1 = int(input("Enter the First Number:-"))#50
num2 = int(input("Enter the Second Number:-"))#2
swap1=num1
num1=num2
num2=swap1
print("first swapping:-",(num1))
print("second swaping:-",(num2))
# Out:
# first swapping:- 2
# second swaping:- 50

# %%
#12. Print multiple values
name ="Shreyas"
age = 18
city="Pune"
print("Name:-",name,"Age:-",age,"City:-",city)
# Out:
# Name:- Shreyas Age:- 18 City:- Pune

# %%
#13. Formatted output
name = "Shreyas"
age = 18

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Shreyas and I am 18 years old.

# %%
#14. Input string and print
'''user_name = str(input("enter the name:-"))#if we dont use {str}then aslo the answer get us in str.
###we only use class words{int,float,etc}for we take a number.
# ## if we dont give (str)then also the answer come in string
print(type(user_name),user_name)#to check that its a string or not'''

#clean version
user_name = input("Enter the name: ")
print(user_name)
# Out:
# shreyas

# %%
#15. Print type of input
a = input("enter the name:")#gives the answer in string.
b = int(input("Enter the number:-"))## give the answer in integer.
c = float(input("Enter the number:-"))## give the answer in float.
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
